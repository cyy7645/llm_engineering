# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['#main',
#  '#footer',
#  'https://www.anthropic.com/',
#  'https://www.anthropic.com/claude',
#  'https://www.anthropic.com/max',
#  'https://www.anthropic.com/team',
#  'https://www.anthropic.com/enterprise',
#  'https://www.anthropic.com/pricing',
#  'https://claude.ai/download',
#  'https://claude.ai/',
#  'https://www.anthropic.com/news/claude-character',
#  'https://www.anthropic.com/api',
#  'https://docs.anthropic.com/',
#  'https://www.anthropic.com/pricing#api',
#  'https://console.anthropic.com/',
#  'https://docs.anthropic.com/en/docs/welcome',
#  'https://www.anthropic.com/solutions/agents',
#  'https://www.anthropic.com/solutions/coding',
#  'https://www.anthropic.com/solutions/customer-support',
#  'https://www.anthropic.com/solutions/education',
#  'https://www.anthropic.com/solutions/financial-services',
#  'https://www.anthropic.com/customers',
#  'https://www.anthropic.com/research',
#  'https://www.anthropic.com/economic-index',
#  'https://www.anthropic.com/claude/opus',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/claude/haiku',
#  'https://www.anthropic.com/news/visible-extended-thinking',
#  'https://www.anthropic.com/transparency',
#  'https://www.anthropic.com/news/announcing-our-updated-responsible-scaling-policy',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/news/anthropic-achieves-iso-42001-certification-for-responsible-ai',
#  'https://www.anthropic.com/customers',
#  'https://www.anthropic.com/engineering',
#  'https://www.anthropic.com/learn',
#  'https://www.anthropic.com/company',
#  'https://www.anthropic.com/careers',
#  'https://www.anthropic.com/events',
#  'https://www.anthropic.com/engineering/building-effective-agents',
#  'https://www.anthropic.com/news',
#  '#',
#  'https://claude.ai/login',
#  'https://claude.ai/download',
#  'https://www.anthropic.com/',
#  'https://www.anthropic.com/claude',
#  'https://www.anthropic.com/max',
#  'https://www.anthropic.com/team',
#  'https://www.anthropic.com/enterprise',
#  'https://www.anthropic.com/pricing',
#  'https://claude.ai/download',
#  'https://claude.ai/',
#  'https://www.anthropic.com/news/claude-character',
#  'https://www.anthropic.com/api',
#  'https://docs.anthropic.com/',
#  'https://www.anthropic.com/pricing#api',
#  'https://console.anthropic.com/',
#  'https://docs.anthropic.com/en/docs/welcome',
#  'https://www.anthropic.com/solutions/agents',
#  'https://www.anthropic.com/solutions/coding',
#  'https://www.anthropic.com/solutions/customer-support',
#  'https://www.anthropic.com/solutions/education',
#  'https://www.anthropic.com/solutions/financial-services',
#  'https://www.anthropic.com/customers',
#  'https://www.anthropic.com/research',
#  'https://www.anthropic.com/economic-index',
#  'https://www.anthropic.com/claude/opus',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/claude/haiku',
#  'https://www.anthropic.com/news/visible-extended-thinking',
#  'https://www.anthropic.com/transparency',
#  'https://www.anthropic.com/news/announcing-our-updated-responsible-scaling-policy',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/news/anthropic-achieves-iso-42001-certification-for-responsible-ai',
#  'https://www.anthropic.com/customers',
#  'https://www.anthropic.com/engineering',
#  'https://www.anthropic.com/learn',
#  'https://www.anthropic.com/company',
#  'https://www.anthropic.com/careers',
#  'https://www.anthropic.com/events',
#  'https://www.anthropic.com/engineering/building-effective-agents',
#  'https://www.anthropic.com/news',
#  '#',
#  'https://claude.ai/login',
#  'https://claude.ai/download',
#  'https://www.anthropic.com/research#entry:8@1:url',
#  'https://www.anthropic.com/claude',
#  'https://claude.ai/',
#  'https://www.anthropic.com/api',
#  'https://anthropic.com/news/claude-4',
#  'https://www.anthropic.com/claude/opus',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/news/core-views-on-ai-safety',
#  'https://www.anthropic.com/rsp-updates',
#  'https://www.anthropic.com/learn',
#  'https://www.anthropic.com/research/project-vend-1',
#  'https://www.anthropic.com/research/agentic-misalignment',
#  'https://www.anthropic.com/news/claude-4',
#  'https://www.anthropic.com/research/tracing-thoughts-language-model',
#  'https://www.anthropic.com/economic-index',
#  'https://www.anthropic.com/news/model-context-protocol',
#  'https://www.anthropic.com/jobs',
#  'https://www.anthropic.com/jobs',
#  'https://www.anthropic.com/contact-sales',
#  'https://www.anthropic.com/claude',
#  'https://www.anthropic.com/claude-code',
#  'https://www.anthropic.com/max',
#  'https://www.anthropic.com/team',
#  'https://www.anthropic.com/enterprise',
#  'https://claude.ai/download',
#  'https://www.anthropic.com/pricing',
#  'http://claude.ai/login',
#  'https://www.anthropic.com/api',
#  'https://docs.anthropic.com/',
#  'https://www.anthropic.com/amazon-bedrock',
#  'https://www.anthropic.com/google-cloud-vertex-ai',
#  'https://www.anthropic.com/pricing#anthropic-api',
#  'https://console.anthropic.com/',
#  'https://www.anthropic.com/research',
#  'https://www.anthropic.com/economic-index',
#  'https://www.anthropic.com/claude/opus',
#  'https://www.anthropic.com/claude/sonnet',
#  'https://www.anthropic.com/claude/haiku',
#  'https://www.anthropic.com/transparency',
#  'https://www.anthropic.com/responsible-scaling-policy',
#  'https://trust.anthropic.com/',
#  'https://www.anthropic.com/solutions/coding',
#  'https://www.anthropic.com/solutions/agents',
#  'https://www.anthropic.com/solutions/customer-support',
#  'https://www.anthropic.com/solutions/education',
#  'https://www.anthropic.com/solutions/financial-services',
#  'https://www.anthropic.com/learn',
#  'https://www.anthropic.com/customers',
#  'https://www.anthropic.com/engineering',
#  'https://www.anthropic.com/partners/mcp',
#  'https://www.anthropic.com/partners/powered-by-claude',
#  'https://www.anthropic.com/company',
#  'https://www.anthropic.com/careers',
#  'https://www.anthropic.com/events',
#  'https://www.anthropic.com/news',
#  'https://www.anthropic.com/startups',
#  'https://status.anthropic.com/',
#  'https://www.anthropic.com/supported-countries',
#  'https://support.anthropic.com/',
#  'https://www.anthropic.com/legal/cookies',
#  'https://www.anthropic.com/legal/privacy',
#  'https://www.anthropic.com/responsible-disclosure-policy',
#  'https://www.anthropic.com/legal/consumer-terms',
#  'https://www.anthropic.com/legal/commercial-terms',
#  'https://www.anthropic.com/legal/aup',
#  'https://www.youtube.com/@anthropic-ai',
#  'https://www.linkedin.com/company/anthropicresearch',
#  'https://x.com/AnthropicAI']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://www.anthropic.com/company'},
#   {'type': 'careers page', 'url': 'https://www.anthropic.com/careers'},
#   {'type': 'team page', 'url': 'https://www.anthropic.com/team'},
#   {'type': 'news page', 'url': 'https://www.anthropic.com/news'},
#   {'type': 'events page', 'url': 'https://www.anthropic.com/events'},
#   {'type': 'research page', 'url': 'https://www.anthropic.com/research'},
#   {'type': 'learn page', 'url': 'https://www.anthropic.com/learn'},
#   {'type': 'transparency page',
#    'url': 'https://www.anthropic.com/transparency'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# 5 days ago
# •
# 14.4k
# •
# 867
# zai-org/GLM-4.5
# Updated
# 1 day ago
# •
# 919
# •
# 537
# bosonai/higgs-audio-v2-generation-3B-base
# Updated
# about 19 hours ago
# •
# 82.5k
# •
# 429
# tencent/HunyuanWorld-1
# Updated
# 1 day ago
# •
# 5.43k
# •
# 400
# Qwen/Qwen3-235B-A22B-Instruct-2507
# Updated
# about 5 hours ago
# •
# 18.5k
# •
# 546
# Browse 1M+ models
# Spaces
# Running
# 11.1k
# 11.1k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 212
# 212
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# Running
# 211
# 211
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# Running
# 197
# 197
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Running
# on
# Zero
# MCP
# 1.14k
# 1.14k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 32.1k
# •
# 8.48k
# interstellarninja/hermes_reasoning_tool_use
# Updated
# 6 days ago
# •
# 1.1k
# •
# 68
# NousResearch/Hermes-3-Dataset
# Updated
# 18 days ago
# •
# 5.93k
# •
# 256
# MegaScience/MegaScience
# Updated
# 5 days ago
# •
# 2.41k
# •
# 49
# microsoft/rStar-Coder
# Updated
# 9 days ago
# •
# 9.64k
# •
# 157
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 776 models
# •
# 3.7k followers
# AI at Meta
# Enterprise
# company
# •
# 2.2k models
# •
# 6.97k followers
# Amazon
# company
# •
# 20 models
# •
# 3.32k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 22.1k followers
# Intel
# company
# •
# 229 models
# •
# 2.79k followers
# Microsoft
# company
# •
# 418 models
# •
# 13.9k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 171 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,623
# State-of-the-art AI models for PyTorch
# Diffusers
# 29,979
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,366
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,799
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,940
# Fast tokenizers optimized for research & production
# TRL
# 14,792
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,231
# State-of-the-art ML running directly in your browser
# smolagents
# 21,644
# Smol library to build great agents in Python
# PEFT
# 19,162
# Parameter-efficient finetuning for large language models
# Datasets
# 20,431
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,368
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,978
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 51,196
# AI & ML interests
# The AI community building the future.
# Recent Activity
# XciD
# new
# activity
# about 5 hours ago
# huggingface/InferenceSupport:
# Qwen/Qwen3-30B-A3B-Instruct-2507
# sayakpaul
# updated
# a dataset
# about 9 hours ago
# huggingface/diffusers-metadata
# lysandre
# updated
# a dataset
# about 21 hours ago
# huggingface/transformers-metadata
# View all activity
# Articles
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# 7 days ago
# •
# 29
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 48
# Team members
# 211
# +177
# +164
# +143
# +133
# +113
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.5M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 797k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.12M
# •
# •
# 799
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.5M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 797k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.12M
# •
# •
# 799
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 15
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# Jun 27
# pinned
# Running
# on
# CPU Upgrade
# 15
# Hugging Face Fast
# 🏎
# Test Hugging Face bandwidth
# huggingface
# Jun 12
# pinned
# Running
# 96
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# on
# CPU Upgrade
# 190
# Inference Playground
# 🔋
# Set theme for Hugging Face Playground
# huggingface
# 8 days ago
# Running
# on
# CPU Upgrade
# 18
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# Jun 18
# Running
# 449
# AI Deadlines
# ⚡
# Manage project deadlines efficiently
# huggingface
# Jun 8
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 3.43k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 17
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.08k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 17
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 2.62k
# •
# 10
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 170
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 2.41k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 16
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 53k
# •
# •
# 82
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# about 9 hours ago
# •
# 72
# •
# 514
# •
# 7
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 21 hours ago
# •
# 1.79k
# •
# 1.11k
# •
# 26
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 22 hours ago
# •
# 55
# •
# 2.74M
# •
# 77
# huggingface/policy-docs
# Viewer
# •
# Updated
# 10 days ago
# •
# 26
# •
# 2.53k
# •
# 13
# huggingface/badges
# Viewer
# •
# Updated
# 12 days ago
# •
# 1
# •
# 419k
# •
# 45
# huggingface/cats-image
# Viewer
# •
# Updated
# Jun 20
# •
# 1
# •
# 11.5k
# •
# 2
# huggingface/label-files
# Updated
# Jun 12
# •
# 2.29k
# •
# 19
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 44
# •
# 1
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 49
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 87
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Say hello to `hf`: a faster, friendlier Hugging Face CLI ✨
# By
# Wauplin
# July 25, 2025
# •
# 53
# Community Articles
# view all
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 13 days ago
# •
# 124
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 7 days ago
# •
# 19
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 10 days ago
# •
# 15
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 103
# LLMGameHub: How We Won the Gradio Agents & MCP Hackathon 2025
# By
# kikikita
# and 1 other
# •
# 1 day ago
# •
# 8
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 322
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 11 days ago
# •
# 47
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 133
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 194
# AI Companionship: Why We Need to Evaluate How AI Systems Handle Emotional Bonds
# By
# giadap
# and 2 others
# •
# 8 days ago
# •
# 7
# Detecting Beyond Sight: Building AI-Enabled SAR Intelligence with Synthetic Data
# By
# DualityAI-RebekahBogdanoff
# •
# 4 days ago
# •
# 4
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# Jun 26
# •
# 36
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# about 1 month ago
# •
# 12
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 21 days ago
# •
# 34
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 19 days ago
# •
# 46
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 12 days ago
# •
# 58
# Test-Driving the LLMD Inference Engine by ZML 🚀
# By
# erikkaum
# •
# 11 days ago
# •
# 21
# Understanding Model Reasoning Through Thought Anchors: A Comparative Study of Qwen3 and DeepSeek-R1
# By
# codelion
# •
# 7 days ago
# •
# 3
# Introducing any-llm: A unified API to access any LLM provider
# By
# mozilla-ai
# and 1 other
# •
# 7 days ago
# •
# 3
# 🧠 MyMories `.mmr` – Compressed Memory Recall for LLM Continuity
# By
# B4S1C
# •
# 3 days ago
# •
# 3
# Parquet Content-Defined Chunking
# By
# kszucs
# July 25, 2025
# •
# 45
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# By
# orrzohar
# July 23, 2025
# •
# 29
# Fast LoRA inference for Flux with Diffusers and PEFT
# By
# sayakpaul
# July 23, 2025
# •
# 34
# Arc Virtual Cell Challenge: A Primer
# By
# FL33TW00D-HF
# July 18, 2025
# •
# 40
# Consilium: When Multiple LLMs Collaborate
# By
# azettl
# July 17, 2025
# guest
# •
# 17
# Back to The Future: Evaluating AI Agents on Predicting Future Events
# By
# vinid
# July 17, 2025
# guest
# •
# 26
# Five Big Improvements to Gradio MCP Servers
# By
# freddyaboulton
# July 17, 2025
# •
# 18
# Seq vs Seq: the Ettin Suite of Paired Encoders and Decoders
# By
# orionweller
# July 16, 2025
# •
# 50
# Migrating the Hub from Git LFS to Xet
# By
# jsulz
# July 15, 2025
# •
# 23
# Asynchronous Robot Inference: Decoupling Action Prediction and Execution
# By
# fracapuano
# July 10, 2025
# •
# 37
# ScreenEnv: Deploy your full stack Desktop Agent
# By
# A-Mahla
# July 10, 2025
# •
# 56
# Building the Hugging Face MCP Server
# By
# evalstate
# July 10, 2025
# •
# 51
# Reachy Mini - The Open-Source Robot for Today's and Tomorrow's AI Builders
# By
# thomwolf
# July 9, 2025
# •
# 614
# Creating custom kernels for the AMD MI300
# By
# ror
# July 9, 2025
# •
# 43
# Previous
# 1
# 2
# 3
# ...
# 44
# Next
# Community Articles
# Sort:
# 		Trending
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 13 days ago
# •
# 124
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 7 days ago
# •
# 19
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 10 days ago
# •
# 15
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 103
# LLMGameHub: How We Won the Gradio Agents & MCP Hackathon 2025
# By
# kikikita
# and 1 other
# •
# 1 day ago
# •
# 8
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 322
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 11 days ago
# •
# 47
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 133
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 194
# AI Companionship: Why We Need to Evaluate How AI Systems Handle Emotional Bonds
# By
# giadap
# and 2 others
# •
# 8 days ago
# •
# 7
# Detecting Beyond Sight: Building AI-Enabled SAR Intelligence with Synthetic Data
# By
# DualityAI-RebekahBogdanoff
# •
# 4 days ago
# •
# 4
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# Jun 26
# •
# 36
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# about 1 month ago
# •
# 12
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 21 days ago
# •
# 34
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 19 days ago
# •
# 46
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 12 days ago
# •
# 58
# Test-Driving the LLMD Inference Engine by ZML 🚀
# By
# erikkaum
# •
# 11 days ago
# •
# 21
# Understanding Model Reasoning Through Thought Anchors: A Comparative Study of Qwen3 and DeepSeek-R1
# By
# codelion
# •
# 7 days ago
# •
# 3
# Introducing any-llm: A unified API to access any LLM provider
# By
# mozilla-ai
# and 1 other
# •
# 7 days ago
# •
# 3
# 🧠 MyMories `.mmr` – Compressed Memory Recall for LLM Continuity
# By
# B4S1C
# •
# 3 days ago
# •
# 3
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 591 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at Hugging Face 🤗 | Making AI work for libraries, archives, and their communities
# 23h
# Report this post
# HF Jobs just launched - and here's how to get started in seconds! 🚀
#
# I extracted text from thousands of classified UFO documents with one command:
#
# ```
# hf jobs uv run --flavor l4x1 \
# https://lnkd.in/e3JyYPsD
# \
#  davanstrien/ufo-ColPali davanstrien/ufo-ocr
# ```
#
# From aged government documents with typewriter text, stamps, and handwriting → clean, searchable markdown. All powered by Nanonets-OCR-s, a state-of-the-art vision-language model that handles LaTeX, tables, forms, and complex layouts. Running on cloud GPUs with zero setup.
#
# This is the power of HF Jobs + uv Scripts:
# - No local GPU needed
# - No dependency management
# - Scripts are self-contained with inline metadata
# - Pay only for compute time used
#
# The uv Scripts organization (
# huggingface.co/uv-scripts
# ) is building a collection of ready-to-run ML tools:
# - VLM-based OCR for any documents
# - Text classification with structured outputs
# - PDF to dataset conversion
# - High-performance vLLM inference
#
# Each script works instantly - just `hf jobs uv run [script] [args]` and you're processing data on A100s.
#
# Big thanks to
# Charlie Marsh
# and the
# Astral
# team for building uv - this amazing tooling makes it all possible!
#
# What repetitive ML task would save you time if it were a one-command script? Drop a comment below - would love to hear what the community needs!
# 202
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 19h
# Report this post
# Serving LLMs? Turns out 𝐩𝐲𝐭𝐡𝐨𝐧 𝐢𝐬 𝐀𝐋𝐋 𝐲𝐨𝐮 𝐧𝐞𝐞𝐝!
# Hugging Face
# transformers now includes a built-in LLM inference server. Pair it with
# Gradio
# , and you can spin up a fully local, private chat UI with any LLM hosted on the Hugging Face Hub – all in just two lines of code!
# …more
# 440
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,820 followers
# 1d
# Edited
# Report this post
# 📢 Integrate your business backends into any MCP-compatible LLM!!
#
# 👉 👉 Transform OpenAPI Specs to MCP servers in One Line!
# Earlier: Manually map API endpoints to MCP tools. Time-consuming + error-prone.
# Now: Automated process with Gradio👇 Single line implementation!
#
# Key features:
# * Browse the UI and filter the endpoints that matter
# * Host your MCP server for free on
# Hugging Face
# * Complete No code solution 🤯
# …more
# 113
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,820 followers
# 4d
# Edited
# Report this post
# 📢WILD! You'll soon be able to build IMMERSIVE apps in Python🤯 stay tuned for more ..
# …more
# 82
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,820 followers
# 4d
# Report this post
# Vibe editor built into your local experience!🤩
#
# Coming soon, stay tuned fam!
# …more
# 111
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 3d
# Edited
# Report this post
# The new transformers release comes w/ a surprise: kernels support ⚡️
#
# It integrates deeply with precompiled kernels on the HF Hub.
#
# - opt-in, automatic kernels for your hardware and software
# - kernels like FA2/3 w/o compilation
# - community-built kernels, for inference & training
#
# This is not simply a speed-up, but also a memory reduction: run bigger models, faster.
#
# We're working with kernel providers like
# Unsloth AI
# ,
# Red Hat
# ,
# vLLM
# ,
# ggml
# and others so that kernels they build are reused across runtimes, from their Hub org.
# 216
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Brigitte Tousignant
# Comms 🤗
# 4d
# Report this post
# It’s not about the race for the frontier but the race for the global AI ecosystem, which can only be achieved by developing more open-source and open-weight models to deploy locally.
# Hugging Face
# Chief Policy Officer
# Irene Solaiman
# joined Ed Ludlow &
# Caroline Hyde
# on
# Bloomberg News
# to discuss our key takeaways from the U.S. AI Action Plan.
# …more
# 69
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# PyTorch
# 286,012 followers
# 4d
# Report this post
# SmolLM3-3B-8da4w: With TorchAO and optimum-executorch, quantizing and exporting SmolLM3 for mobile deployment is a breeze! 🎉
#
# Our quantized model is ready for efficient deployment on-device with ExecuTorch, running at 15 tokens/sec on Galaxy S22! 🤯
#
# See our model card on HuggingFace for recipes and quantized checkpoints:
# 🔗
# https://hubs.la/Q03yGBnJ0
# #LLM
# #EdgeAI
# #PyTorch
# #Quantization
# pytorch/SmolLM3-3B-8da4w · Hugging Face
# huggingface.co
# 286
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# JetBrains
# 367,937 followers
# 6d
# Report this post
# The rise of specialized LLMs is accelerating.
#
# Not every developer task requires a state-of-the-art-LLM level of intelligence. For some, a specialized smaller model is enough to deliver precision and speed at a much lower cost.
#
# At JetBrains, we’re betting on that future – and we’ve just open-sourced Mellum, our task-specific focal LLM for code completion.
#
# Join us and Hugging Face for a livestream on why focal models matter, how they complement general-purpose LLMs, and what this means for the next generation of AI-native developer tools.
#
# 📅 July 29, 6 pm CET
#
# 👉 Save your spot:
# https://jb.gg/1vbq8c
# Live Webinar -
# info.jetbrains.com
# 110
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 5d
# Report this post
# Turns out Kimi K2 is pretty impressive for creative use cases like electronic music composition!
#
#
#
# Vibe tested with
# Hugging Face
# comparing it to other open frontier models.
#
#
# Just load the dataset from the link in the comments or start vibe testing with your ideas:
# https://lnkd.in/dVu2f2SB
# …more
# 27
# 1 Comment
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nGet started with Inference in seconds 🚀\nReachy Mini: The Open Robot for AI Builders\nWelcome Cohere on the Hub 🔥\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/Qwen3-Coder-480B-A35B-Instruct\nUpdated\n5 days ago\n•\n14.4k\n•\n867\nzai-org/GLM-4.5\nUpdated\n1 day ago\n•\n919\n•\n537\nbosonai/higgs-audio-v2-generation-3B-base\nUpdated\nabout 19 hours ago\n•\n82.5k\n•\n429\ntencent/HunyuanWorld-1\nUpdated\n1 day ago\n•\n5.43k\n•\n400\nQwen/Qwen3-235B-A22B-Instruct-2507\nUpdated\nabout 5 hours ago\n•\n18.5k\n•\n546\nBrowse 1M+ models\nSpaces\nRunning\n11.1k\n11.1k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n212\n212\nHiggs Audio Demo\n🎤\nHiggs Audio Demo\nRunning\n211\n211\nMulti-Style Video-to-Anime Generator\n📊\nTransfer your videos with different AnimeStyles & havefun!\nRunning\n197\n197\nQwen3 Coder WebDev\n🌍\nGenerate web application code from descriptions\nRunning\non\nZero\nMCP\n1.14k\n1.14k\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n32.1k\n•\n8.48k\ninterstellarninja/hermes_reasoning_tool_use\nUpdated\n6 days ago\n•\n1.1k\n•\n68\nNousResearch/Hermes-3-Dataset\nUpdated\n18 days ago\n•\n5.93k\n•\n256\nMegaScience/MegaScience\nUpdated\n5 days ago\n•\n2.41k\n•\n49\nmicrosoft/rStar-Coder\nUpdated\n9 days ago\n•\n9.64k\n•\n157\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n776 models\n•\n3.7k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.2k models\n•\n6.97k followers\nAmazon\ncompany\n•\n20 models\n•\n3.32k followers\nGoogle\nEnterprise\ncompany\n•\n1.04k models\n•\n22.1k followers\nIntel\ncompany\n•\n229 models\n•\n2.79k followers\nMicrosoft\ncompany\n•\n418 models\n•\n13.9k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n171 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n317 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n147,623\nState-of-the-art AI models for PyTorch\nDiffusers\n29,979\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,366\nSafe way to store/distribute neural network weights\nHub Python Library\n2,799\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,940\nFast tokenizers optimized for research & production\nTRL\n14,792\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,231\nState-of-the-art ML running directly in your browser\nsmolagents\n ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face!
#
# ### The AI Community Building the Future
#
# At Hugging Face, we're fostering a vibrant community dedicated to advancing artificial intelligence. Our collaborative platform is designed for machine learning enthusiasts and developers to share, explore, and innovate in the field of AI. We’re proud to host over **1 million machine learning models** and **250,000 datasets**, making it easier than ever for creators and researchers to work together.
#
# ---
#
# ### What We Offer
#
# - **Models**: Browse and deploy a diverse range of state-of-the-art machine learning models—over 1 million to choose from.
# - **Datasets**: Access more than 250,000 datasets tailored for various ML tasks to accelerate your projects.
# - **Spaces**: Explore and create applications seamlessly through our innovative Spaces platform.
# - **Enterprise Solutions**: Enhance your organization’s AI capabilities with our enterprise-grade offerings tailored for security, collaboration, and support.
#
# ---
#
# ### Our Customers
#
# Join the ranks of over **50,000 organizations** leveraging our platform, including industry leaders such as:
# - **Meta**
# - **Google**
# - **Microsoft**
# - **Amazon**
#
# Whether you are a small startup or a large enterprise, Hugging Face provides the tools and support to elevate your AI projects.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we prioritize collaboration and community. Our ethos is built upon:
# - **Open Source Contribution**: We believe in the power of open-source technology to democratize AI and foster innovation.
# - **Diversity and Inclusion**: We celebrate diverse ideas and perspectives, striving to create an inclusive environment where everyone feels valued and empowered.
# - **Continuous Learning**: We encourage our team and users to continuously learn, share knowledge, and grow together.
#
# ---
#
# ### Careers at Hugging Face
#
# Join us in the mission to build the future of AI! We are always on the lookout for talented individuals who are passionate about machine learning and AI. Explore available positions in engineering, product management, research, and community outreach on our [Jobs page](https://huggingface.co/jobs).
#
# ---
#
# ### Get Started Today!
#
# Dive into the world of AI with Hugging Face—whether you're a researcher, developer, or data scientist.
# - **Sign Up**: Create an account to access models, datasets, and apps.
# - **Documentation**: Explore our [Docs](https://huggingface.co/docs) for guides and tutorials to ramp up your projects.
# - **Community Engagement**: Join discussions on our Forum, or connect with us on [Twitter](https://twitter.com/huggingface), [LinkedIn](https://www.linkedin.com/company/huggingface/) and [Discord](https://discord.gg/huggingface).
#
# ---
#
# **Together, we can shape the future of AI. Welcome to Hugging Face!**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}]}
# # Hugging Face Brochure
#
# ---
#
# ## Welcome to Hugging Face
#
# ### The AI Community Building the Future
#
# At Hugging Face, we are on a mission to democratize machine learning. As a collaborative platform for the machine learning community, we empower individuals and teams to create, discover, and innovate with over **1 million models**, **250,000 datasets**, and a wide range of applications. From AI enthusiasts to enterprises, our platform suits everyone from hobbyists to large corporations!
#
# ---
#
# ### Our Offerings
#
# - **Models**: Explore a vast repository of state-of-the-art AI models for various tasks—ranging from text and image processing to audio and more.
# - **Datasets**: Access and share a diverse collection of datasets tailored for multiple machine learning tasks.
# - **Spaces**: Create and host applications effortlessly, boosting collaboration and creativity within the community.
# - **Enterprise Solutions**: Tailored offerings for teams to enhance their machine learning endeavors with advanced security and dedicated support.
#
# ---
#
# ### Who We Serve
#
# With over **50,000 organizations** leveraging Hugging Face, our platform is trusted by industry leaders including:
#
# - Google
# - Microsoft
# - Amazon
# - Meta
# - Intel
# - Grammarly
#
# Join a diverse community of over **51,000 followers** and leverage our resources to enhance your machine learning projects.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we foster a culture of **collaboration and openness**. As a cornerstone of our mission, we prioritize community engagement and open-source contributions, enabling all users to share their work and insights. Our environment is built on continuous learning, innovation, and an unwavering commitment to addressing the challenges of machine learning today.
#
# ---
#
# ### Careers at Hugging Face
#
# We're always on the lookout for talented individuals to join our mission! Whether you're an experienced engineer, a passionate content creator, or a product manager, there are numerous opportunities to advance your career in a cutting-edge AI and ML environment.
#
# - **Explore Opportunities**: Check our [Jobs Page](https://huggingface.co) for the latest job postings and join us in shaping the future of AI.
#
# ---
#
# ### Connect with Us
#
# We invite you to embark on your AI journey with Hugging Face.
#
# - **Join the Community**: Follow us on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), [LinkedIn](https://www.linkedin.com/company/huggingface), and [Discord](https://discord.com/invite/huggingface)!
# - **Get Started**: Sign up at [huggingface.co](https://huggingface.co) and start leveraging our powerful tools and resources today!
#
# ---
#
# Together, let’s build the future of AI! 🚀

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
